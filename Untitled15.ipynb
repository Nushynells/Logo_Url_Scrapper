# %%
#Import Libraries
 
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
#read the companies from the csv file

csvCompanies=pd.read_csv("keni.csv")

#Replace nulls with empty strings
csvCompanies.fillna('',inplace=True)

# %%
#loop through all the website urls 

for link in csvCompanies['website']:
    #find the index of the row e.g. website link on the first row will be 0
    
    loc=csvCompanies[csvCompanies["website"]==link].index[0]
    try:
        #send request to speed it up make it async
        page=requests.get(link,allow_redirects=True)
        
        #get the beautifulsoup object of the page
        soup=BeautifulSoup(page.text,'lxml')
        #loop through all images
        for img_el in soup.find_all('img'):
            #if the string logo is in img src or alt or class attribute
            #take the url using the position of the website link
            #add the url in its logo column
            if 'logo' in img_el['src'] or img_el['alt']:
                if len(csvCompanies["logo"].loc[loc])==0:
                    csvCompanies["logo"].loc[loc]=img_el['src']
                elif'logo'in ''.join(img_el['class']):
                    csvCompanies["logo"].loc[loc]=img_el['src']
                    
    except:
            print(link)
# Out:
# http://www.rushingtap.com
# http://MAJIFINA.COM
# http://proads4u.weebly.com
# http://www.naicity.co.ke
# https://hostwebr.com
# http://www.potafrica.com
# http://web4africa.co.ke
# http://www.kenhatgsc.com
# http://www.cisikenya.com
# http://www.damarahotel.com
# http://galaxisglobal.com/
# http://www.safariadventureskenya.com
# http://www.downtownbackpackers.co.ke
# http://garoda.com
# http://www.theboma.co.ke
# http://www.kigothohotel.com
# http://www.eHotels.co.ke
# http://www.parkplacehotel.co.ke
# http://www.mirehtravel.com
# http://www.feathertrailtours.com
# http://www.africakenyasafari.com
# https://tai-beach-house-lamu.business.site/?_target?m=true
# http://www.wilddreamliners.com
# http://www.safaris.starwoodHotelskenya.com
# http://www.safarihunters.net
# http://www.nairobi-mombasa-train-booking.com
# http://www.kenyatrainbooking.com
# http://www.hotelradiancekenya.com/
# https://www.bwexecutiveresidencynairobi.co.ke/
# http://www.cityroyalkampala.com
# http://www.africaheartsafaris.com
# http://www.adventuremytake.com
# /listings/http:\\www.irokoHotels.kbo.co.ke
# http://www.dimasafaris.com
# http://www.biglifesafaris.com
# http://www.elmolocrocodilepark.com
# http://www.royaltonhotelcomplex.com
# http://www.polskenecotours.com
# http://www.plenser.com
# http://www.mochahotel.co.ke
# http://www.mimosacourt.com
# http://hartebeestcamp.com
# http://www.fischerstowers.com
# http://www.ajtoursandsafaris.com
# http://www.67airporthotel.co.ke
# http://www.africanpremieradventures.com
# http://www.tailoredhost.com
# http://bizsmart.co.ke/
# https://www.garanntor.co.ke
# http://www.afrokat.com
# http://www.mybrandhost.com
# https://nodeafrica.com/
# http://www.bridgelinksites.com
# /listings/http:/www.brandfiesta.com
# http://www.justhire.co.ke
# http://www.madein-kenya.com
# http://www.kenscopeshipping.com
# http://www.jamodesigns.com
# http://www.digitaledge-interactive.com
# http://www.carsearch.co.ke
# http://www.raftinginkenya.com
# http://preeminent.co.ke
# http://www.noticeboardke.com
# http://www.handshakesocialmedia.co.ke
# https://fixsattamatka.com/
# https://apexlistings.co.ke
# http://www.africanspicesafaris.com/
# http://www.transfertsafaris.com
# http://www.rochlillysafaris.com
# http://www.marandovulodge.com
# https://leorentals.com
# http://www.dancomtours.com
# http://www.afrikalodges.co.ke
# http://www.taidys.co.ke
# http://www.sairock.co.ke
# https://www.facebook.com/Manrik-Group-Ltd-354069084625374/
# http://www.inksholtel.com
# http://www.arc.egerton.ac.ke
# https://supreme-destinations.com
# http://www.qlikksoft.com
# https://orawebhost.com/
# http://www.betawebcomputers.com
# https://tupoahosting.co.ke
# http://itbrothersinc.com
# http://hakikahost.com
# http://fridweb.com
# http://www.bizpillar.co.ke
# http://www.techfrontiers.co.ke
# http://www.outstechsolutions.com
# http://www.internetkenya.com
# http://enomshop.net
# http://www.deepafrica.com
# http://www.truehost.co.ke
# http://www.softnetsolutions.co.ke
# http://www.skyhost.co.ke
# http://www.simhub.co.ke
# http://www.mtaandao.co.ke
# http://www.enchorowildlifecamp.com
# https://dimehub.com/
# http://www.kitengelabusinesslist.biz
# http://www.hazainagency.com
# http://www.vinsoko.com
# http://www.ipsummedia.co.ke
# http://www.dodwellsolutions.com
# http://webonmobi.com
# http://www.simbacar.com
# https://www.eastafricadigitalmarketers.com
# https://www.catforddigitalmedia.com/
# http://www.catalogmint.com
# http://www.teamkosh.com
# https://www.kenstate.com
# http://www.thenest.co.ke
# https://southriftgalaxysafaris.com
# http://sevengenerations.co.ke/
# http://www.prideinn.co.ke
# http://www.juliustsafaris.com
# http://www.amanitiwibeachresort.com
# http://www.slopesvillahotel.com
# http://www.exclusiveafrika.com
# http://www.msafinihotel.co.ke
# https://www.hilton.com/en/Hotels/nbohudi-doubletree-nairobi-hurlingham/
# http://www.stoniathiresort.com
# https://www.marachui.com
# https://www.likizolettings.co.ke
# https://www.hilton.com/en/Hotels/nboapgi-hilton-garden-inn-nairobi-airport/
# http://www.hillparktiwibeach.com
# http://giorgisafaris.com
# http://www.ngorongotea.com
# http://www.homecomforts.co.ke
# http://www.kentradehorizons.co.ke
# http://WEGOS.COM.YE
# http://www.diademgrains.com
# http://Www.afribon.com
# http://www.whitecow.co.ke
# http://www.lindas-healthy-diets.com
# http://www.equatorbottlers.co.ke/
# https://popularnutrifoodskeltd.blogspot.co.ke/
# http://www.minesoftwares.com
# http://www.jambonex.com
# http://www.internetkenya.com
# http://www.ecl-kenya.com
# http://www.enetonlinesolutions.co.ke
# http://www.cecypo.com
# https://254sun.co.ke
# http://www.stratech.co.ke
# https://solitechsolutions.com
# http://shujaahost.co.ke
# http://www.movetechsolutions.com
# http://www.cloudafrica.co.ke
# http://www.bithost.co.ke
# https://webdrawers.co.ke
# https://web-hosting-kenya.co.ke
# https://www.tel.co.ke
# http://www.pwanihost.com
# https://www.hostpinnacle.co.ke
# https://www.ecyber.co.ke
# http://www.budhahost.com
# https://bebahost.co.ke
# http://www.ashergroupltd.com
# http://www.wisetec.co.ke
# http://www.tricomlinksolutions.com
# http://www.fasajenterpises.co.ke
# http://Www.logicdesigns.co.ke
# http://www.karentmedia.com
# http://www.capitaledgeonline.co.ke
# http://www.adcar.co.ke
# http://www.kenyaelephantinternatioal.com
# http://www.designtech.co.ke
# http://www.picturesquekenya.biz
# http://yellowpageskenya.com
# http://www.nightingaledigital.com/
# http://www.malindifunnymap.com
# http://www.linkwithbiz.com
# http://www.housenex.com
# http://www.trinfinity.co/
# http://www.smartcoinventures.com
# http://www.tancolabproducts.com
# http://www.mkazipro.com
# https://www.sokoradar.co.ke
# http://www.pncee.co.ke
# http://www.edirectoryke.com
# https://www.toodaa.com
# http://teleticksolutions.com
# http://www.stockpot.co.ke
# http://www.sambazah.net
# http://www.pivot.co.ke
# http://www.zarmacaron.ir
# http://www.barada.bloombiz.com
# http://www.galashia.com
# http://www.queenschateau.com
# http://www.kibokokenyasafaris.com/
# http://www.jetsonafrica.com
# http://www3.hilton.com/en/Hotels/kenya/hilton-nairobi-nbohitw/index.html?wt.mc_id=zelwakn0emea1hi2dmh3localsearch4dggenericx6nbohitw
# http://www.explorerswild.com
# http://www.santokicountryresorts.com
# http://www.oranjesafari.nl
# http://www.huntsmansafaris.com/
# http://www.bookingskenya.com
# http://www.faharigardenshotel.co.ke
# http://www.thesironplace.com
# http://www.shalomhotelkenya.com
# https://www.facebook.com/Panesic-hotel-778090718977676/
# http://www.africahomeadventure.com
# http://www.sunshinehotel.co.ke
# http://www.eaexoticsafaris.com
# http://www.thebigfiveadventures.com
# http://www.savannatrails.com
# http://www.shuhanhotelkabati.co.ke
# http://www.nalepomaralodge.com
# https://www.cheetahsafaris.co.ke
# http://www.blueocean-safaris.com
# http://www.ipac.co.ke
# http://www.alphafinefoods.com
# http://www.sceptermillers.com
# https://hamletfeeds.wixsite.com/hamletfeeds
# http://www.kenblestgroup.com
# http://www.rongdar.com
# https://www.baj.co.ke
# http://www.magnapater.co.ke
# http://www.firstcupcoffee.co.ke
# http://eaccl.co.ke/
# http://www.peafood.co.ke
# https://www.facebook.com/edarnsenterprisesltd
# http://www.cakeworld.co.ke
# https://www.facebook.com/FineBlendz/
# http://www.slotozilla.com
# http://www.neemus.co.ke
# http://www.justinweb.net
# http://www.juliwebconsultancy.co.ke
# http://www.intelixsolutions.net
# https://hostnali.com/
# http://esamict.co.ke
# http://www.amisigenuine.host
# https://www.africanidentitytech.com
# http://www.adpro.co.ke
# https://bensonakuma.co.ke
# http://www.jumpsystems.co.ke
# https://www.cloudpap.com/
# http://afrisol.co.ke/
# https://patahost.com
# http://www.bomanisolutions.co.ke
# http://www.greenbox.co.ke
# https://www.claire.co.ke
# https://www.ehostkenya.com
# https://cyberpro.co.ke/
# http://tandabuisolutions.com
# http://www.crablinks.co.ke
# http://www.websolutions.co.ke
# http://www.handycreations.biz
# http://www.vidahostkenya.com
# https://geniusdynamics.co.ke
# http://barcodeskenya.com/
# http://crystalgreeneastafrica.weebly.com/
# http://www.brucewardconsultants-ea.com
# http://www.indepthresearch.org
# http://www.airealtd.com
# http://www.acuityresearch.co.ke
# https://publicworkske.wordpress.com/director-kbrc/
# http://www.tabisonresearc.co.ke
# http://www.affinity.co.ke
# http://www.ndotoafricaresearch.com
# http://www.frontierconsulting.co.ke
# http://www.biggerpockets.com/co/bobstats-consulting
# http://statssolutionskenya.Co. ke
# https://www.research8020.com
# http://www.airea.co.ke
# http://www.biztrace.co.ke
# http://www.magiccolours.co.ke
# http://www.becamanzagency.co.ke
# http://www.pixelads.co.ke
# http://www.lukeaire.com
# http://www.kiogutwauniforms.com
# https://www.soccertoritvshow.blogspot.com/
# http://www.autotrader.co.ke
# http://www.phenomdigital.co.ke
# http://fameidols.com
# http://www.uchumiquick.com
# http://www.el-spice.com
# http://www.eaglesandangelsng.com
# http://blackschoolrecords.com
# http://www.mediamasterltd.com
# http://enthronedstudios.com
# http://www.signsevolution.co.ke
# http://www.rhodium.co.ke
# https://phenom-media.co.ke
# http://www.digimatrixtech.com
# http://www.ems-creations.com
# http://www.designmaxmedia.co.ke
# http://getsales.co.ke/
# http://www.blisstourskenya.co.ke
# http://www.treline.co.ke/
# http://www.bestfoodsng.com
# http://www.teampesa.com
# http://www.svs.xyz
# http://www.lenasi.co.ke
# http://admoran.com/
# http://www.lifebergfoods.com
# https://www.xpatworld.co.ke
# http://yummytummies.com.ng
# http://www.psychmarketing.co.ke
# http://www.ayrishdigital.com
# https://www.johndigital.co.ke
# http://www.higanicreative.co.ke
# http://www.nikohapa.com/
# http://www.viralgorrrila.com
# http://www.backpackersfaris.com
# http://www.netlitdigital.com
# https://www.glowbal.co.ke
# http://www.smartfarmerkenya.com
# http://www.e-ssesh.net
# http://www.mgfglobal.com
# http://screenplayafrica.com
# http://www.filmfactoryng.com
# http://www.genuinemarketing.co.ke
# http://www.nollywoodjobscapital.com
# http://www.soundtech.co.ke
# http://www.powerbrandmedia.co.ke
# http://www.radiosimba.co.ke
# http://quadronstudios.com
# http://www.carterbridgefilms.com
# http://www.epicentermedia.co.ke
# http://www.digitalsocialservices.co.ke
# https://teddyleting.com
# http://www.allebmedia.com
# http://www.nusoftsystems.com
# http://www.hubrif.com
# http://www.diftiinstitute.webs.com
# http://www.smidsanimation.com
# http://nollywoodinsider.com
# https://www.okikemedia.com
# https://swagsfilms.blogspot.com
# http://www.gist.ng/
# https://www.facebook.com/filmgeekspro
# http://www.africaeconews.com/
# http://www.raptvmedia.com
# http://www.mcrystal.com.ng
# http://www.filmservicemedia.com
# http://www.startupmagazine.co.ke
# http://thelonewolfproduction.com/
# http://sidomexuniversal.com/
# https://exposeke.com/
# http://www.titansmedia.com
# http://www.triceinteractive.net
# http://www.buruburuonline.co.ke
# http://www.niyaleolimited.com
# http://www.axismedia.co.ke
# https://typemium.com
# http://www.georgebensons.com
# http://www.shabbassnails.bloombig.com
# http://www.3d-alive.net
# http://www.lehuien.industrialmanufacturer.net/refferences/refferences.html
# http://tupesa.co.ke
# https://vivibossafrifarms.company.site/
# https://m.facebook.com/Theschoolp/?__tn__=C-R
# http://www.swiftconnections.co.ke
# http://www.horizontechdesigns.co.ke
# http://www.discoucher.com
# https://www.beliefmagazine.wordpress.com
# http://www.mebofarms.com
# https://zettasolutions.co.ke/
# http://www.guruconsultancy.co.ke
# http://www.kituinewspaper.com
# http://Www.jubiinvestmentsltd@co.ke
# http://www.mysterypublisherslimited.com
# http://www.advancelitho.co.ke
# http://www.epitomedesigns.co.ke
# http://www.universalkenya.com/
# http://martcy2000.wixsite.com/deviantstore
# http://www.advancelitho.co.ke
# http://johndigitalsolutions.com/
# https://www.nairobimind.com
# http://www.dilevlimited.weebly.com
# http://www.centrestage.co.ke
# http://businessweekly.co.ke
# http://www.ornico.co.za
# http://www.freemason.co.ke
# http://www.itboxkenya.com
# http://www.cuttingedge.co.ke
# http://habariconsulting.com
# http://www.designstudiosafrica.com
# https://www.starmarketingcompany.wordpress.com
# http://michaelwabomba.co.ke
# http://mukuba.co.ke
# http://graylinemediagroup.co.ke/
# http://www.b2bconsulting.co.ke
# http://urbanwright.com
# http://gstrategiccommunications.com
# https://www.artfuleyes.com
# http://sponge.co.ke/
# https://afc.co.ke
# http://www.skydrive.co.ke
# http://www.magazinereel.com
# https://axiosdigitallabs.com/
# http://www.murban-eng.com
# https://xenomenergy.com/
# https://purpleslighting.wixsite.com/purpleslightingcom
# http://www.jeffilms.com.ng
# http://www.dalbitinternational.com/
# http://www.houseofstablemedia.com
# http://www.dancevilleng.com
# http://www.richworldinvestments.co.uk
# http://www.boxofficestudios.com
# http://www.uvisualstudios.com
# https://www.facebook.com/nanodoctorafrica
# http://phoenixfilms4u.wix.com/phoenix-films
# http://www.getgas.co.ke
# http://www.yabatechfilmacademy.com
# http://www.onalmultimedia.com
# http://www.alongsideetv.com
# http://www.saintoniosstudio.com
# http://blazegist.com
# https://www.facebook.com/officialsqfilms/
# http://www.houseofmega.com
# https://www.purpleslightingco.wordpress.com
# http://www.georgeugwuja.com.ng
# http://www.ewtv.tv
# http://www.hibeepictures.com
# http://www.immediaconcept.com
# http://www.jworldntertainment.com.ng
# http://www.morgeez.com
# http://www.g2entertainmentworld.com
# https://biz.antvt.com
# http://www.novoisioro.com
# http://www.modifoods.ng.org
# https://fb.me/oakondiments
# http://www.mayalhealthyproducts.simplesite.com
# http://www.glophconcept.com
# /listings/http/www.afro-foods.com
# http://www.sheryllace.credencecapital.com.ng
# https://thenutplaceng.com
# https://glovanfarms.com/
# http://www.alder-holdings.com
# https://mekz-global.com
# http://www.winosafoods.com
# http://www.coconuhubng.com
# https://purebliss.ng/
# http://www.anadariya.com
# http://www.novelexpresstastyfoods.com
# http://www.kemasproducts.com
# http://www.jelneng.com
# http://www.afroplux.org.ng
# http://www.eaglesoncassava.com
# https://cartonsproducer.catalog.to/s/cartons-producer--manufacturers-packaging--printing-services/cartons-producer--manufacturer-lagos-nigeria/eaf
# http://www.omaryfoods.com
# http://www.oasisgroup.com.ng
# http://www.petblowingmachine.com
# http://konetmills.simdif.com
# http://www.dmccboxes.com.ng
# http://www.propackaging.com.ng
# http://www.feedwellsupport.com
# https://www.facebook.com/dovelzobong
# http://www.careyoutpackaging.com/shop
# https://cartonsproducer.catalog.to/s/cartons-producer--manufacturers-packaging--printing-services/cartons-producer--manufacturer-lagos-nigeria/eaf
# http://www.teruke.com
# http://titoyoghurt.com
# http://callmycabng.com
# https://abujaambulanceservices.business.site
# http://www.skyleveltravels.com
# http://www.bmaxglobal.com.ng
# https://www.solozic.com/
# https://www.facebook.com/primanovacab
# http://www.grandcapitalhotel.com.ng
# http://flyboku.com
# https://discountHotels.com.ng/Hotels/index.php
# https://destinali.com
# http://www.casavalleta.com.ng
# http://www.fingerprintshotel.com
# http://www.avoirevolticnig.com
# http://www.wontra.com
# http://www.westelevenluxury.com
# https://travelden.com
# http://www.somersetct.com
# http://www.phronesisng.com
# http://www.starboardrealtors.com.ng
# http://crystalbeds.com.ng
# http://www.chiscotransport.com.ng
# http://www.benautoguesthouse.com
# http://www.wsih.com.ng
# http://www.vvanigeria.com
# https://www.travelbeta.com/
# https://enterprise.temydee.com
# http://www.reenytravels.com
# http://www.nelsonwealthtravel.com/
# http://ihotelvest.com
# https://www.activ360.com.ng
# http://www.platinumapartments-suites.com
# http://www.1stfortyhotel.com
# http://www.aitechl.com
# http://www.everydaygroup.com
# https://trendorhotel.com
# http://www.travelmastersng.com
# https://purplecrownhotel.com
# http://www.diamonddemerald.com
# http://www.hotel-presidential.com
# http://www.golfprincehotel.com
# http://www.kakanfoinn.com
# http://jomaphHotels.com.ng/
# https://travelsandlodge.com/
# http://sinonilodge.com
# http://www.toprankhotelabuja.com
# http://www.sunrisehotel.com.ng
# http://www.hillsidegardenslagos.com
# http://www.accountsreports.com
# http://www.smridus.com
# https://academysuites.com
# http://www.shollybest.com
# http://www.hawthornabuja.com
# https://www.zithus.com/
# https://www.swift.ng/
# http://www.ndkconsult.com.ng
# http://www.centoriagroup.com
# http://www.dominionconsulting.com.ng
# http://www.aa91.ng
# http://perfecthavens.biz
# http://www.Hotels.ng
# http://www.burgeonhillsHotels.com
# http://www.leparishotel.com.ng
# http://www.hotelnewcastlelagos.com
# http://www.finserveng.com
# https://listings360.com.ng
# http://www.essentialtravelsng.com
# http://www.whitefieldHotels.com
# http://www.chasetravelsng.com
# http://www3.hilton.com/en/Hotels/nigeria/transcorp-hilton-abuja-abuhitw/index.html?wt.mc_id=zelwakn0emea1hi2dmh3localsearch4dggenericx6abuhitw
# http://www.nexus318.com
# http://www.quietpoolsinn.com
# http://www.marblefieldhotel.com
# https://www.leparishotel.com.ng
# http://www.grandeurtravelsng.com
# http://www.ennydanielstravels.com
# http://www.destinationconnectdmc.com
# http://degrandroyalpalacehotel.com/
# http://www.thecaesarshotel.com
# http://www.achebe.ng
# http://rovedana.com
# https://www.fscprofessionals.com
# https://getinsurance.ng
# http://www.emiloju.com
# http://www.mcseagroup.com
# https://www.jscglobalaccountingservices.com
# http://www.wessels-accounting.co.za
# http://www.innerkonsult.com
# https://www.jscglobalaccountingservices.com
# http://www.lafunhotel.com
# http://www.oakspringhotelng.com
# http://www.logosng.com
# http://www.zioskytravels.com
# http://www.wibdanguesthouse.com
# https://www.marshaltravelsandtours.com/
# http://htttp://abuja.frasershospitality.com
# http://www.dynaxtravel.com
# http://www.unveilingroyalty.com.ng
# /listings/http;/www.orchardHotels.com.ng
# http://www.ehh.com.ng
# http://www.chillasgarden.com
# http://www.celiasuites.com
# http://www.bristolpalacehotel.com
# http://www.lopterraservices.com
# http://www.yourtaxinow.com
# http://www.aumtco.com
# http://www.spyydd.com
# http://www.kenworldz.com
# http://www.panlogtrans.com
# http://www.tourbasedynamic.com
# /listings/http/www.kezandhonours.com
# http://www.executivecabservices.com/
# http://Debonisworld.com
# http://www.karringtontravels.com
# http://www.jidoy.org
# http://www.frontidaltd.com
# https://lapromessahotel.com/
# http://dixiesuites.com.ng/
# https://www.defranklin.com
# http://www.citadelsuiteslimited.com
# http://www.citadelsuiteslimites.com
# http://www.crownedgeHotels.com
# http://www.westparkhotel.com.ng
# http://nsdcsuites.com
# https://www.ninaHotels.com.ng/
# http://www.intelligentHotelsng.com/
# http://bellahomesng.com
# http://www.sisatravels.com/
# https://rentyourhall.com/
# http://esetravels.com
# http://bespokevacationsng.com
# http://www.prestherconsul.com
# http://www.efad-ng.com
# http://www.essienukpong.com
# http://www.taishaaccountingservices.com.ng
# http://raywhite-folorunsho.com/
# http://www.oaugf.gov.ng
# http://www.edempeters.com
# http://www.humbletigerprofessionals.net
# http://www.dacaconsults.com
# http://www.zadocandpartners.com
# http://www.masalconsultants.com
# http://www.bbsvdechange.com
# http://www.delivrixlogistics.com.ng
# http://carmart.ng
# http://www.yesboss.com.ng
# http://www.sparespace.com.ng
# http://www.rhezon.com
# http://www.questcarhire.com
# http://www.flowcabng.com
# http://www.emmynath.com
# http://www.obatglobal.com
# http://ezmoov.com
# http://bizpointcommercials.com
# http://www.beatams.com
# https://www.rentalcarnigeria.com
# http://www.reallionmultiventures.com
# http://www.mosdyke.com
# https://tdsptravelsandtours.com.ng
# http://www.tccogere.com
# http://www.ngride.com
# https://www.pskyconnects.com/
# https://ishakoolHotels.com/
# http://www.fawzyHotels.com/
# https://cheekersinn.business.site/
# https://afaritravels.com
# http://www.torimatechnology.com
# http://logistics/hospitality
# http://www.treasureparkng.com
# http://www.quztan.com
# http://wwww.splendourtravels.coms
# http://www.royalparkng.com
# https://www.facebook.com/morningsidesuite/
# http://www.hplinktravels.com
# http://epossolutions.com.ng
# http://www.debmusassociates.com/
# http://librosoft.net
# http://www.debmusassociates.com
# http://www.zadocandpartners.com
# http://taishaaccountingservices.com.ng
# http://praecognitioconsulting.com.ng
# http://www.michelleandanthony.net/
# http://www.lolaruthassociates.com
# http://www.sac.com.ng
# http://www.sapl.com.ng
# http://www.rightwayaccountant.com
# http://www.tabsandicons.com
# http://www.accountingpro.ng
# http://yusufogundare.com
# http://www.jcgoldgroup.com
# https://gigm.com
# http://www.042cabs.com.ng
# http://www.beeshoplogistics.com
# http://www.autotechtracker.com
# http://www.bitslogistics.com
# https://www.protaxiapp.ng/
# http://www.motustek.com
# http://www.globecabservices.com
# http://www.capitalplusgroupng.com
# https://autoplatform.ng
# http://www.capitolcabs.com.ng
# http://www.poshcarrental.com.ng
# http://www.patjedagroup.com
# http://www.laimangroupng.com
# http://www.daelautos.com
# http://www.jospet.com.ng
# http://www.stakeride.com
# http://cedarexpressng.com/
# http://www.alcredogroup.com
# http://no
# http://www.greatwoodHotels.com
# http://www.goldentulipibadan.com
# https://topranohotel.com
# http://www.deestravelnigeria.com
# http://cottonsuites.com
# http://www.diplomatHotelsng.com
# http://www.royaltiestours.com
# http://www.aeroporttravels.com
# /listings/https/Hotels.mobiashara.com/nowoola-palace-hotel
# http://www.bedouinHotelsltd.com
# https://www.cargolandmaritime.com
# https://www.kitienergy.com
# http://www.kisumuventureltd.com
# https://llpsltd.com/
# https://distinctcushy.com
# http://www.autobesttrackers.com.ng
# http://www.cargohub.ng
# http://www.soloziccars.com
# https://afriqline.business.site/
# https://www.redoxcorp.com/
# http://www.cartracking.com.ng
# http://www.acornglobal.net
# https://www.facebook.com/glorylogistics
# http://www.urban-inc.eu
# https://www.burkont.com.ng
# http://www.afroprexsuservices.com
# http://timo.com.ng
# https://www.ollysealenergy.com/
# http://www.dilivad.com
# http://www.ibicxpress.com
# http://www.logistix.ng
# https://ishop-worldwide.com
# http://www.turboerrands.com
# http://www.bowagateglobal.com
# http://www.atlasrelocator.com
# https://tifatravels.com/
# http://wilsonjaymovers.com.ng
# http://www.hillcrestprofessionalsng.com
# http://www.khome.com.ng
# http://www.iykautoworld.com
# http://www.tegsolconsulting.com
# http://www.safegatemfb.com
# http://www.finserve.com.ng
# http://www.mcseagroup.com
# http://www.quisave.com.ng
# http://www.senomuoja-ng.com
# https://www.hellovti.jimdo.com
# http://www.fimide.com
# http://www.jemcapitalplus.com
# http://www.virtualaccountant.ng
# http://www.accountinghub.ng
# https://alphapartnerstrainings.com
# http://www.wforoedl.com
# http://ecbs.webnode.com
# http://www.goldenmuv.com
# http://www.peachprofessionals.com
# http://www.sowprofessional.com
# http://refinedfinance.com.ng
# http://www.deeno.com.ng
# https://e2esupplychain.net/
# http://rexfordcarrentals.business.site
# http://www.prestigeautosng.com
# https://www.mgemservices.com
# http://www.gatlogistics,ng
# http://www.fgtransport.ng
# http://www.tatautowash.com
# http://www.parmcltd.com
# http://www.increasecars.com.ng
# http://www.eazyhire.com.ng
# http://www.daitransltd.com
# https://corporatemovers247.business.site
# http://www.ocenj.com
# http://www.callbob.ng
# http://www.xclusiverentacar.org.ng
# http://www.eazyhire.com.ng
# http://www.daitransltd.com
# https://corporatemovers247.business.site
# http://www.ocenj.com
# http://www.callbob.ng
# http://www.xclusiverentacar.org.ng
# http://www.reelverge.com
# http://www.swissspiritHotels.com/danag-portharcourt

# %%
csvCompanies.to_excel("sunday.xlsx")
csvCompanies
# Out:
#                                                 Name  \
# 0                                        Rushing Tap
# 1                            MAJIFINA Purified Water
# 2                                           Proads4U
# 3                         Naicity Business Directory
# 4                                           Hostwebr
# ..                                               ...
# 891                                  Ocenj Logistics
# 892                                 Call Bob Nigeria
# 893                              Xclusive Rent A Car
# 894                                Reelverge Limited
# 895  Swiss Spirit Hotel & Suites Danag Port Harcourt
#
#                                                website logo_link
# 0                            http://www.rushingtap.com
# 1                                  http://MAJIFINA.COM
# 2                           http://proads4u.weebly.com
# 3                             http://www.naicity.co.ke
# 4                                 https://hostwebr.com
# ..                                                 ...       ...
# 891                               http://www.ocenj.com
# 892                              http://www.callbob.ng
# 893                 http://www.xclusiverentacar.org.ng
# 894                           http://www.reelverge.com
# 895  http://www.swissspiritHotels.com/danag-porthar...
#
# [896 rows x 3 columns]
